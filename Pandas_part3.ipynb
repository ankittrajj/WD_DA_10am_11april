# %%
import pandas as pd

# %%
#task----> to import data to python
df = pd.read_csv(r'C:\Users\Satyam\Downloads\Indian Startup.csv')

# %%
df.head()
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
# 4  PayGlocal is a FinTech solving for global paym...
#
#                                         Founder/s  \
# 0                                    Ruchir Arora
# 1                          Anshul Gupta, Amit Raj
# 2                        Nitya, Chaitra Chidanand
# ...

# %%
df.isnull().sum()
# Out:
# Company/Brand      0
# Founded            1
# Headquarters       1
# Sector             0
# What it does       0
# Founder/s          4
# Investor/s        63
# Amount             7
# Stage            428
# Date               0
# dtype: int64

# %%
df.shape
# Out:
# (1209, 10)

# %%
# drop
df.head()
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
# 4  PayGlocal is a FinTech solving for global paym...
#
#                                         Founder/s  \
# 0                                    Ruchir Arora
# 1                          Anshul Gupta, Amit Raj
# 2                        Nitya, Chaitra Chidanand
# ...

# %%
df1 = df.drop(['Company/Brand'],axis=1)

# %%
df.head()
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
# 4  PayGlocal is a FinTech solving for global paym...
#
#                                         Founder/s  \
# 0                                    Ruchir Arora
# 1                          Anshul Gupta, Amit Raj
# 2                        Nitya, Chaitra Chidanand
# ...

# %%
df1
# Out:
#       Founded Headquarters                            Sector  \
# 0      2015.0      Gurgaon                        E-learning
# 1      2012.0       Mumbai                  Food & Beverages
# 2      2015.0    Bangalore                 Consumer Services
# 3      2018.0       Mumbai  Venture Capital & Private Equity
# 4      2021.0    Bangalore                Financial Services
# ...       ...          ...                               ...
# 1204   2019.0       Mumbai                            EdTech
# 1205   2020.0    New Delhi                            EdTech
# 1206   1978.0    Bangalore                     BioTechnology
# 1207   2020.0       Mumbai                        E-commerce
# 1208   2018.0      Gurgaon                        Healthcare
#
#                                            What it does  \
# 0     Collegedekho.com is Student’s Partner, Friend ...
# 1                      India's Largest Desi Meals Brand
# 2     Simpl empowers merchants to build trusted rela...
# ...

# %%
# dropna
x = df.dropna()

# %%
x
# Out:
#      Company/Brand  Founded Headquarters                Sector  \
# 0     CollegeDekho   2015.0      Gurgaon            E-learning
# 2            Simpl   2015.0    Bangalore     Consumer Services
# 4        PayGlocal   2021.0    Bangalore    Financial Services
# 6        Pocket FM   2018.0    Bangalore                   OTT
# 8      PlanetSpark   2017.0     Gurugram  Education Management
# ...            ...      ...          ...                   ...
# 1201           Oyo   2012.0      Gurgaon           Hospitality
# 1202       Agri10x   2018.0         Pune              AgriTech
# 1204      HobSpace   2019.0       Mumbai                EdTech
# 1207    KiranaKart   2020.0       Mumbai            E-commerce
# 1208         Meddo   2018.0      Gurgaon            Healthcare
#
#                                            What it does  \
# 0     Collegedekho.com is Student’s Partner, Friend ...
# 2     Simpl empowers merchants to build trusted rela...
# ...

# %%
x.isnull().sum()
# Out:
# Company/Brand    0
# Founded          0
# Headquarters     0
# Sector           0
# What it does     0
# Founder/s        0
# Investor/s       0
# Amount           0
# Stage            0
# Date             0
# dtype: int64

# %%
x.shape
# Out:
# (736, 10)

# %%
df.shape
# Out:
# (1209, 10)

# %%
# serching
#loc & iloc
# loc----> location based serching
# iloc----> index based location searching
df.loc()

# %%
df.loc[df['Sector']=='OTT']
# Out:
#   Company/Brand  Founded Headquarters Sector  \
# 6     Pocket FM   2018.0    Bangalore    OTT
#
#                                         What it does  \
# 6  Pocket FM lets users discover and enjoy the gr...
#
#                                  Founder/s  \
# 6  Rohan, Nishanth Srinivas, Prateek Dixit
#
#                                           Investor/s       Amount     Stage  \
# 6  Lightspeed, Times Group, Tanglin Venture Partners  $22,000,000  Series B
#
#       Date
# 6  Dec-2021

# %%
df.loc[df['Company/Brand']=='Meddo']
# Out:
#      Company/Brand  Founded Headquarters      Sector  \
# 822          Meddo   2018.0     Gurugram  Healthcare
# 1208         Meddo   2018.0      Gurgaon  Healthcare
#
#                                            What it does  \
# 822   Meddo (Arctern Healthcare) are re-defining how...
# 1208   Meddo is an end-to-end medical services provider
#
#                                 Founder/s  \
# 822   Saurabh Kochhar, Dr Naveen Nishchal
# 1208                      Saurabh Kochhar
#
#                                       Investor/s      Amount         Stage  \
# 822   SRI Capital, Picus Capital, Alkemi Capital  $6,000,000           NaN
# 1208            growX ventures, Venture Gurukool  $3,000,000  Pre-series A
#
#          Date
# 822   Jun-2021
# 1208  Jan-2021

# %%
# use loc to search the data from df
# 1. find the name & founded year of edtech comapnies.
df
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
# 1. find the name & founded year of edtech + e-comm comapnies.
df.loc[df['Sector']=='EdTech' , df['Sector']=='E-commerce'][['Company/Brand','Founded','Headquarters']]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8508/2953603297.py in <module>
#       1 # 1. find the name & founded year of edtech + e-comm comapnies.
# ----> 2 df.loc[df['Sector']=='EdTech' , df['Sector']=='E-commerce'][['Company/Brand','Founded','Headquarters']]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
# ...

# %%
df.loc[df['Sector']=='EdTech',['Company/Brand','Founded']]

# %%
df2=df.loc[df["Sector"]=="EdTech"][["Company/Brand","Founded"]]
df2

# %% [markdown]
# # Pandas Part 4

# %%
#  find the name & founded year of edtech + e-comm comapnies.
df[df['Sector'] == ['EdTech','E-commerce']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8508/924843459.py in <module>
#       1 #  find the name & founded year of edtech + e-comm comapnies.
# ----> 2 df[df['Sector'] == ['EdTech','E-commerce']]
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      30     @unpack_zerodim_and_defer("__eq__")
#      31     def __eq__(self, other):
# ---> 32         return self._cmp_method(other, operator.eq)
#      33
#      34     @unpack_zerodim_and_defer("__ne__")
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
# ...

# %%
df.loc[df('Sector')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8508/1764613874.py in <module>
# ----> 1 df.loc[df('Sector')]
#
# TypeError: 'DataFrame' object is not callable

# %%
#  find the name & founded year of edtech + e-comm comapnies.
df[df['Sector']=='EdTech']
# Out:
#             Company/Brand  Founded Headquarters  Sector  \
# 186                BYJU'S   2011.0    Bangalore  EdTech
# 192   Sunstone Eduversity   2011.0     Gurugram  EdTech
# 254                Questt   2020.0     Gurugram  EdTech
# 372             EventBeep   2019.0         Pune  EdTech
# 382              Tinkerly   2015.0       Jaipur  EdTech
# ...                   ...      ...          ...     ...
# 1181             Pariksha   2015.0         Pune  EdTech
# 1189          Practically   2018.0    Telangana  EdTech
# 1195                  Kyt   2020.0    Bangalore  EdTech
# 1204             HobSpace   2019.0       Mumbai  EdTech
# 1205              DcodeAI   2020.0    New Delhi  EdTech
#
#                                            What it does  \
# 186   BYJU’S is India's largest ed-tech company and ...
# 192   Sunstone Eduversity is a one-of-its-kind busin...
# 254   Questt is a Free online homework app that lets...
# 372   An inclusive community where students are insp...
# ...

# %%
df.head()
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
# 4  PayGlocal is a FinTech solving for global paym...
#
#                                         Founder/s  \
# 0                                    Ruchir Arora
# 1                          Anshul Gupta, Amit Raj
# 2                        Nitya, Chaitra Chidanand
# ...

# %%
df.loc[:3]
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
#
#                   Founder/s                   Investor/s       Amount  \
# 0              Ruchir Arora             Disrupt ADQ, QIC  $35,000,000
# 1    Anshul Gupta, Amit Raj                 Tiger Global  $40,000,000
# 2  Nitya, Chaitra Chidanand  Valar Ventures, IA Ventures  $40,000,000
# ...

# %%
sector= df[(df['Sector']=='EdTech')  |  (df['Sector']=='E-commerce') | (df['Headquarters']=='Mumbai')]

# %%
df['Sector']=='E-commerce'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1204    False
# 1205    False
# 1206    False
# 1207     True
# 1208    False
# Name: Sector, Length: 1209, dtype: bool

# %%
sector
# Out:
#      Company/Brand  Founded Headquarters      Sector  \
# 70        Yodacart   2019.0        Thane  E-commerce
# 72           Zepto   2021.0    Bangalore  E-commerce
# 97      GlobalBees   2021.0    New Delhi  E-commerce
# 103          Zepto   2021.0       Mumbai  E-commerce
# 124      Troo Good   2018.0    Hyderabad  E-commerce
# ...            ...      ...          ...         ...
# 1195           Kyt   2020.0    Bangalore      EdTech
# 1199         Udaan   2016.0    Bangalore  E-commerce
# 1204      HobSpace   2019.0       Mumbai      EdTech
# 1205       DcodeAI   2020.0    New Delhi      EdTech
# 1207    KiranaKart   2020.0       Mumbai  E-commerce
#
#                                            What it does  \
# 70    YODACART is an e-commerce startup offering rea...
# 72    Ability to consistently deliver 2,500+ product...
# 97    Globalbees partners with entrepreneurs who hav...
# 103                            Grocery delivery startup
# ...

# %%
sector.shape[0]
# Out:
# 139

# %%
sector
# Out:
#      Company/Brand  Founded Headquarters                             Sector  \
# 1             BOX8   2012.0       Mumbai                   Food & Beverages
# 3      8i Ventures   2018.0       Mumbai   Venture Capital & Private Equity
# 9       LenDenClub   2015.0       Mumbai                 Financial Services
# 10       CometChat   2009.0       Mumbai                  Computer Software
# 12         Bizongo   2015.0       Mumbai  Information Technology & Services
# ...            ...      ...          ...                                ...
# 1199         Udaan   2016.0    Bangalore                         E-commerce
# 1203     BlackSoil   2016.0       Mumbai                            FinTech
# 1204      HobSpace   2019.0       Mumbai                             EdTech
# 1205       DcodeAI   2020.0    New Delhi                             EdTech
# 1207    KiranaKart   2020.0       Mumbai                         E-commerce
#
# ...

# %%
sector = df[(df['Sector']=='EdTech')   & (df['Headquarters']=='Mumbai')]

# %%
sector
# Out:
#         Company/Brand  Founded Headquarters  Sector  \
# 396   Genext Students   2013.0       Mumbai  EdTech
# 516        Expertrons   2019.0       Mumbai  EdTech
# 530            upGrad   2015.0       Mumbai  EdTech
# 632       CareerNinja   2017.0       Mumbai  EdTech
# 691         SpEd@home   2020.0       Mumbai  EdTech
# 771       Skillmatics   2016.0       Mumbai  EdTech
# 846          Mentoria   2015.0       Mumbai  EdTech
# 858         Klassroom   2016.0       Mumbai  EdTech
# 887            upGrad   2015.0       Mumbai  EdTech
# 888       Lead School   2012.0       Mumbai  EdTech
# 1148      BeyondSkool   2020.0       Mumbai  EdTech
# 1168      PurpleTutor   2019.0       Mumbai  EdTech
# 1204         HobSpace   2019.0       Mumbai  EdTech
#
#                                            What it does  \
# 396   LIVE online classes with expert tutors for K-1...
# 516   The world's largest AI Videobot platform provi...
# 530   upGrad is India’s largest online higher educat...
# ...

# %%
sector=df.loc[((df['Sector']=='EdTech') | (df['Sector']=='E-commerce')) & (df['Headquarters']=='Mumbai'),['Company/Brand','Founded','Sector','Headquarters']]

# %%
sector
# Out:
#         Company/Brand  Founded      Sector Headquarters
# 103             Zepto   2021.0  E-commerce       Mumbai
# 295           Purplle   2012.0  E-commerce       Mumbai
# 396   Genext Students   2013.0      EdTech       Mumbai
# 516        Expertrons   2019.0      EdTech       Mumbai
# 530            upGrad   2015.0      EdTech       Mumbai
# 632       CareerNinja   2017.0      EdTech       Mumbai
# 691         SpEd@home   2020.0      EdTech       Mumbai
# 727         QuickSell   2017.0  E-commerce       Mumbai
# 771       Skillmatics   2016.0      EdTech       Mumbai
# 846          Mentoria   2015.0      EdTech       Mumbai
# 858         Klassroom   2016.0      EdTech       Mumbai
# 887            upGrad   2015.0      EdTech       Mumbai
# 888       Lead School   2012.0      EdTech       Mumbai
# 895            Taikee   2010.0  E-commerce       Mumbai
# 934           Beldara   2018.0  E-commerce       Mumbai
# 1093        Pepperfry   2011.0  E-commerce       Mumbai
# ...

# %%
sector= df[(df['Sector']=='EdTech')  |  (df['Sector']=='E-commerce')],[['Company/Brand','Founded','Sector']]

# %%
sector
# Out:
# (     Company/Brand  Founded Headquarters      Sector  \
#  70        Yodacart   2019.0        Thane  E-commerce
#  72           Zepto   2021.0    Bangalore  E-commerce
#  97      GlobalBees   2021.0    New Delhi  E-commerce
#  103          Zepto   2021.0       Mumbai  E-commerce
#  124      Troo Good   2018.0    Hyderabad  E-commerce
#  ...            ...      ...          ...         ...
#  1195           Kyt   2020.0    Bangalore      EdTech
#  1199         Udaan   2016.0    Bangalore  E-commerce
#  1204      HobSpace   2019.0       Mumbai      EdTech
#  1205       DcodeAI   2020.0    New Delhi      EdTech
#  1207    KiranaKart   2020.0       Mumbai  E-commerce
#
#                                             What it does  \
#  70    YODACART is an e-commerce startup offering rea...
#  72    Ability to consistently deliver 2,500+ product...
#  97    Globalbees partners with entrepreneurs who hav...
#  103                            Grocery delivery startup
# ...

# %%
df['Sector']
# Out:
# 0                             E-learning
# 1                       Food & Beverages
# 2                      Consumer Services
# 3       Venture Capital & Private Equity
# 4                     Financial Services
#                       ...
# 1204                              EdTech
# 1205                              EdTech
# 1206                       BioTechnology
# 1207                          E-commerce
# 1208                          Healthcare
# Name: Sector, Length: 1209, dtype: object

# %%
#dot notation
df.Founded[0]
# Out:
# 2015.0

# %%
df.Sector[0:7]
# Out:
# 0                          E-learning
# 1                    Food & Beverages
# 2                   Consumer Services
# 3    Venture Capital & Private Equity
# 4                  Financial Services
# 5          Health, Wellness & Fitness
# 6                                 OTT
# Name: Sector, dtype: object

# %%
#data manipulation

# drop
# adding new col or rows
# perform aggregation function
# iloc
df.columns
# Out:
# Index(['Company/Brand', 'Founded', 'Headquarters', 'Sector', 'What it does',
#        'Founder/s', 'Investor/s', 'Amount', 'Stage', 'Date '],
#       dtype='object')

# %%
df
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
df[df['Founded']>2018]
# Out:
#         Company/Brand  Founded Headquarters              Sector  \
# 4           PayGlocal   2021.0    Bangalore  Financial Services
# 16    Exponent Energy   2020.0    Bangalore          Automotive
# 17           Trinkerr   2021.0    Bangalore     Capital Markets
# 18              Zorro   2021.0     Gurugram      Social network
# 19      Ultraviolette   2021.0    Bangalore          Automotive
# ...               ...      ...          ...                 ...
# 1195              Kyt   2020.0    Bangalore              EdTech
# 1196            iMumz   2019.0    Bangalore          Healthcare
# 1204         HobSpace   2019.0       Mumbai              EdTech
# 1205          DcodeAI   2020.0    New Delhi              EdTech
# 1207       KiranaKart   2020.0       Mumbai          E-commerce
#
#                                            What it does  \
# 4     PayGlocal is a FinTech solving for global paym...
# 16    Simplifying energy for EVs by building a Flexi...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   Headquarters   1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founder/s      1205 non-null   object
#  6   Investor/s     1146 non-null   object
#  7   Amount         1202 non-null   object
#  8   Stage          781 non-null    object
#  9   Date           1209 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 94.6+ KB

# %%
df['sum_of_founded_year'] = df['Founded'].sum()

# %%
df
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
df['new_Col'] = 'hello'

# %%
df.shape
# Out:
# (1209, 12)

# %%
df
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
df.Founded.sum()
# Out:
# 2436120.0
