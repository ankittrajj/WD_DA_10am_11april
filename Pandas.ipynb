# %%
import pandas as pd

# %%
#wap to make dict!!
x = {
    'name':['ABC','dsfg','rrr','bahuballi'],
    'age':[34,45,56,67],
    'marks':[200,34,52,12]
}

# %%
x
# Out:
# {'name': ['ABC', 'dsfg', 'rrr', 'bahuballi'],
#  'age': [34, 45, 56, 67],
#  'marks': [200, 34, 52, 12]}

# %%
df = pd.DataFrame(x,index=[0,1,2,3])

# %%
df
# Out:
#         name  age  marks
# 0        ABC   34    200
# 1       dsfg   45     34
# 2        rrr   56     52
# 3  bahuballi   67     12

# %%
# Slicing 
df['name'][0]
# Out:
# 'ABC'

# %%
df[['name','marks']]
# Out:
#         name  marks
# 0        ABC    200
# 1       dsfg     34
# 2        rrr     52
# 3  bahuballi     12

# %%
df
# Out:
#         name  age  marks
# 0        ABC   34    200
# 1       dsfg   45     34
# 2        rrr   56     52
# 3  bahuballi   67     12

# %%
#store the data in the form of a file

file = df.to_csv('mynewfile.csv')

# %%
file

# %%
#task----> to import data to python
df1 = pd.read_csv(r'C:\Users\Satyam\Downloads\Indian Startup.csv')

# %%
df1
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
#task to observe data
# head
# tail
# sample
df1.head()
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
# 4  PayGlocal is a FinTech solving for global paym...
#
#                                         Founder/s  \
# 0                                    Ruchir Arora
# 1                          Anshul Gupta, Amit Raj
# 2                        Nitya, Chaitra Chidanand
# ...

# %%
df1.head(10)
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
# 5       Curefit   2016.0    Bangalore        Health, Wellness & Fitness
# 6     Pocket FM   2018.0    Bangalore                               OTT
# 7   CHARGE+ZONE   2018.0     Vadodara                        Automotive
# 8   PlanetSpark   2017.0     Gurugram              Education Management
# 9    LenDenClub   2015.0       Mumbai                Financial Services
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# ...

# %%
# tail
df1.tail(12)
# Out:
#          Company/Brand  Founded Headquarters         Sector  \
# 1197          BharatPe   2018.0    New Delhi        FinTech
# 1198            CropIn   2010.0    Bangalore       AgriTech
# 1199             Udaan   2016.0    Bangalore     E-commerce
# 1200      Vanity Wagon   2018.0      Haryana      Cosmetics
# 1201               Oyo   2012.0      Gurgaon    Hospitality
# 1202           Agri10x   2018.0         Pune       AgriTech
# 1203         BlackSoil   2016.0       Mumbai        FinTech
# 1204          HobSpace   2019.0       Mumbai         EdTech
# 1205           DcodeAI   2020.0    New Delhi         EdTech
# 1206  Biocon Biologics   1978.0    Bangalore  BioTechnology
# 1207        KiranaKart   2020.0       Mumbai     E-commerce
# 1208             Meddo   2018.0      Gurgaon     Healthcare
#
#                                            What it does  \
# 1197  BharatPe develops a QR code-based payment app ...
# 1198  CropIn is a leading AI and Data-led agri-tech ...
# ...

# %%
#sample
df1.sample(3)
# Out:
#         Company/Brand  Founded Headquarters      Sector  \
# 1022  Juicy Chemistry   2014.0   Coimbatore  Healthcare
# 1075            Aisle   2014.0    Bangalore      Dating
# 1019          Chirrup   2020.0    Bangalore      Gaming
#
#                                            What it does  \
# 1022  Juicy Chemistry operates as an eponymous consu...
# 1075  Aisle connects the new generation of single in...
# 1019            Video integrated social-gaming platform
#
#                                       Founder/s  \
# 1022                      Megha, Pritesh Asher.
# 1075                                Able Joseph
# 1019  Vipul Garg, Sourav Lashkari, Mehul Mittal
#
#                                          Investor/s        Amount  \
# 1022                                  Akya Ventures    $6,300,000
# 1075                 Anas Rahman Junaid, Vinod Jose  $Undisclosed
# 1019  Titan Capital, iSeed, First Cheque, 3.0 Fund.      $300,000
#
#              Stage     Date
# ...
