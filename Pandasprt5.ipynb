# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Satyam\Downloads\IPL Matches 2008-2020.csv')

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
# loc 
# iloc----> index based searching!!
df.iloc[0]
# Out:
# id                                      335982
# city                                 Bangalore
# date                                2008-04-18
# player_of_match                    BB McCullum
# venue                    M Chinnaswamy Stadium
# neutral_venue                                0
# team1              Royal Challengers Bangalore
# team2                    Kolkata Knight Riders
# toss_winner        Royal Challengers Bangalore
# toss_decision                            field
# winner                   Kolkata Knight Riders
# result                                    runs
# result_margin                            140.0
# eliminator                                   N
# method                                     NaN
# umpire1                              Asad Rauf
# umpire2                            RE Koertzen
# Name: 0, dtype: object

# %%
df.iloc[0,3]
# Out:
# 'BB McCullum'

# %%
df.iloc[0,5]
# Out:
# 0

# %%
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df.city
# Out:
# 0       Bangalore
# 1      Chandigarh
# 2           Delhi
# 3          Mumbai
# 4         Kolkata
#           ...
# 811         Dubai
# 812         Dubai
# 813     Abu Dhabi
# 814     Abu Dhabi
# 815         Dubai
# Name: city, Length: 816, dtype: object

# %%
#how many time ipl was happen in banglore city.
df.iloc[df[0,1]=='Bangalore']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (0, 1)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.loc[df['city']=='Bangalore']
# Out:
#           id       city        date  player_of_match                  venue  \
# 0     335982  Bangalore  2008-04-18      BB McCullum  M Chinnaswamy Stadium
# 10    335992  Bangalore  2008-04-26        SR Watson  M Chinnaswamy Stadium
# 14    335996  Bangalore  2008-04-28         MS Dhoni  M Chinnaswamy Stadium
# 24    336006  Bangalore  2008-05-05      S Sreesanth  M Chinnaswamy Stadium
# 30    336012  Bangalore  2008-05-28     CRD Fernando  M Chinnaswamy Stadium
# ..       ...        ...         ...              ...                    ...
# 606  1082621  Bangalore  2017-04-27           AJ Tye  M Chinnaswamy Stadium
# 618  1082633  Bangalore  2017-05-05   Sandeep Sharma  M Chinnaswamy Stadium
# 621  1082636  Bangalore  2017-05-07        SP Narine  M Chinnaswamy Stadium
# 633  1082648  Bangalore  2017-05-17  NM Coulter-Nile  M Chinnaswamy Stadium
# 634  1082649  Bangalore  2017-05-19        KV Sharma  M Chinnaswamy Stadium
#
# ...

# %%
df['city'].iloc[0]
# Out:
# 'Bangalore'

# %%
df['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          65
# Hyderabad          64
# Chennai            57
# Chandigarh         56
# Jaipur             47
# Pune               38
# Abu Dhabi          29
# Dubai              26
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Ahmedabad          12
# Sharjah            12
# Centurion          12
# Rajkot             10
# Dharamsala          9
# Indore              9
# Johannesburg        8
# Cuttack             7
# Cape Town           7
# Port Elizabeth      7
# Ranchi              7
# Raipur              6
# Kochi               5
# Kanpur              4
# East London         3
# Kimberley           3
# Nagpur              3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
df.loc[df['city']=='Bengaluru',['city','venue']]
# Out:
#           city                  venue
# 581  Bengaluru  M.Chinnaswamy Stadium
# 643  Bengaluru  M.Chinnaswamy Stadium
# 646  Bengaluru  M.Chinnaswamy Stadium
# 654  Bengaluru  M.Chinnaswamy Stadium
# 659  Bengaluru  M.Chinnaswamy Stadium
# 664  Bengaluru  M.Chinnaswamy Stadium
# 666  Bengaluru  M.Chinnaswamy Stadium
# 686  Bengaluru  M.Chinnaswamy Stadium
# 702  Bengaluru  M.Chinnaswamy Stadium
# 712  Bengaluru  M.Chinnaswamy Stadium
# 715  Bengaluru  M.Chinnaswamy Stadium
# 734  Bengaluru  M.Chinnaswamy Stadium
# 737  Bengaluru  M.Chinnaswamy Stadium
# 744  Bengaluru  M.Chinnaswamy Stadium
# 749  Bengaluru  M.Chinnaswamy Stadium

# %%
df.shape
# Out:
# (816, 17)

# %%
# df["city"=="Bangalore"].value_counts()
df.loc[df['city']=='Bangalore',['player_of_match','team1']]
# Out:
#      player_of_match                        team1
# 0        BB McCullum  Royal Challengers Bangalore
# 10         SR Watson  Royal Challengers Bangalore
# 14          MS Dhoni  Royal Challengers Bangalore
# 24       S Sreesanth  Royal Challengers Bangalore
# 30      CRD Fernando  Royal Challengers Bangalore
# ..               ...                          ...
# 606           AJ Tye  Royal Challengers Bangalore
# 618   Sandeep Sharma  Royal Challengers Bangalore
# 621        SP Narine  Royal Challengers Bangalore
# 633  NM Coulter-Nile          Sunrisers Hyderabad
# 634        KV Sharma               Mumbai Indians
#
# [65 rows x 2 columns]

# %%
#aggregation function
df[['city','venue']].iloc[0:2]
# Out:
#          city                                       venue
# 0   Bangalore                       M Chinnaswamy Stadium
# 1  Chandigarh  Punjab Cricket Association Stadium, Mohali

# %%
# sum,max,min,mean,median,avg,std deviation,percentile
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df['result_margin'].sum()
# Out:
# 13840.0

# %%
df['result_margin'].max()
# Out:
# 146.0

# %%
df['result_margin'].min()
# Out:
# 1.0

# %%
df['result_margin'].mean()
# Out:
# 17.321652065081352

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df.replace('Chandigarh','C')
# Out:
#           id       city        date player_of_match  \
# 0     335982  Bangalore  2008-04-18     BB McCullum
# 1     335983          C  2008-04-19      MEK Hussey
# 2     335984      Delhi  2008-04-19     MF Maharoof
# 3     335985     Mumbai  2008-04-20      MV Boucher
# 4     335986    Kolkata  2008-04-20       DJ Hussey
# ..       ...        ...         ...             ...
# 811  1216547      Dubai  2020-09-28  AB de Villiers
# 812  1237177      Dubai  2020-11-05       JJ Bumrah
# 813  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # Pandas part 6

# %%
replace_city = df.replace('Bangalore','Bengaluru')

# %%
df.loc[replace_city['city']=='Bengaluru'].shape[0]
# Out:
# 80

# %%
df.loc[df['city']=='Bengaluru']
# Out:
#           id       city        date player_of_match                  venue  \
# 581  1082595  Bengaluru  2017-04-08       KM Jadhav  M.Chinnaswamy Stadium
# 643  1136568  Bengaluru  2018-04-13        UT Yadav  M.Chinnaswamy Stadium
# 646  1136571  Bengaluru  2018-04-15       SV Samson  M.Chinnaswamy Stadium
# 654  1136579  Bengaluru  2018-04-21  AB de Villiers  M.Chinnaswamy Stadium
# 659  1136584  Bengaluru  2018-04-25        MS Dhoni  M.Chinnaswamy Stadium
# 664  1136589  Bengaluru  2018-04-29         CA Lynn  M.Chinnaswamy Stadium
# 666  1136591  Bengaluru  2018-05-01      TG Southee  M.Chinnaswamy Stadium
# 686  1136611  Bengaluru  2018-05-17  AB de Villiers  M.Chinnaswamy Stadium
# 702  1175362  Bengaluru  2019-03-28       JJ Bumrah  M.Chinnaswamy Stadium
# 712  1175372  Bengaluru  2019-04-05      AD Russell  M.Chinnaswamy Stadium
# 715  1178395  Bengaluru  2019-04-07        K Rabada  M.Chinnaswamy Stadium
# ...

# %%
#groupby
df.groupby(['team1']).mean()
# Out:
#                                        id  neutral_venue  result_margin
# team1
# Chennai Super Kings          6.753125e+05       0.148936      17.784946
# Deccan Chargers              4.385486e+05       0.256410      14.153846
# Delhi Capitals               1.202348e+06       0.000000      17.647059
# Delhi Daredevils             6.738618e+05       0.132530      17.670732
# Gujarat Lions                1.025441e+06       0.000000       9.866667
# Kings XI Punjab              7.601415e+05       0.086957      18.163043
# Kochi Tuskers Kerala         5.012330e+05       0.000000      19.571429
# Kolkata Knight Riders        7.942457e+05       0.073684      15.282609
# Mumbai Indians               8.087483e+05       0.030928      17.947368
# Pune Warriors                5.512894e+05       0.000000      15.521739
# Rajasthan Royals             7.222976e+05       0.042857      15.260870
# Rising Pune Supergiant       1.082618e+06       0.000000      27.428571
# ...

# %%
df.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
#on the basis of toss_decision what will be the 
# upcoming result.
df.groupby(['toss_decision'])[['winner']].max()
# Out:
# C:\Users\Satyam\AppData\Local\Temp/ipykernel_2520/2696676983.py:3: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby(['toss_decision'])[['winner']].max()
# Empty DataFrame
# Columns: []
# Index: [bat, field]

# %%
df.groupby(["toss_winner"])[["winner"]].max()
# Out:
# C:\Users\Satyam\AppData\Local\Temp/ipykernel_2520/446921108.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby(["toss_winner"])[["winner"]].max()
# Empty DataFrame
# Columns: []
# Index: [Chennai Super Kings, Deccan Chargers, Delhi Capitals, Delhi Daredevils, Gujarat Lions, Kings XI Punjab, Kochi Tuskers Kerala, Kolkata Knight Riders, Mumbai Indians, Pune Warriors, Rajasthan Royals, Rising Pune Supergiant, Rising Pune Supergiants, Royal Challengers Bangalore, Sunrisers Hyderabad]

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df.groupby(['toss_decision','result']).mean()
# Out:
#                                   id  neutral_venue  result_margin
# toss_decision result
# bat           runs     645765.198630       0.150685      28.013699
#               tie      960977.400000       0.200000            NaN
#               wickets  668684.184524       0.125000       6.422619
# field         runs     810572.522936       0.059633      32.178899
#               tie      882998.250000       0.125000            NaN
#               wickets  818904.966292       0.071161       6.202247

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
#on the basis of city arrange the data into 
# assending/descending order.
df.groupby(["toss_decision","result"]).agg({"result_margin":["max"]}).reset_index()
# Out:
#   toss_decision   result result_margin
#                                    max
# 0           bat     runs         111.0
# 1           bat      tie           NaN
# 2           bat  wickets          10.0
# 3         field     runs         146.0
# 4         field      tie           NaN
# 5         field  wickets          10.0

# %%
df.sort_values("city")
# Out:
#           id       city        date player_of_match  \
# 405   729293  Abu Dhabi  2014-04-21        SK Raina
# 416   729315  Abu Dhabi  2014-04-29     JP Faulkner
# 412   729307  Abu Dhabi  2014-04-26  Sandeep Sharma
# 411   729305  Abu Dhabi  2014-04-26        PV Tambe
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# ..       ...        ...         ...             ...
# 410   729303        NaN  2014-04-25       MM Sharma
# 413   729309        NaN  2014-04-27         M Vijay
# 414   729311        NaN  2014-04-27        DR Smith
# 415   729313        NaN  2014-04-28  Sandeep Sharma
# 417   729317        NaN  2014-04-30         B Kumar
#
#                                    venue  neutral_venue  \
# 405                 Sheikh Zayed Stadium              1
# 416                 Sheikh Zayed Stadium              1
# 412                 Sheikh Zayed Stadium              1
# 411                 Sheikh Zayed Stadium              1
# ...

# %%
df.groupby(by ='city',sort=False)
# Out:
#                       id  neutral_venue  result_margin
# city
# Bangalore       44083928              0         1480.0
# Chandigarh      41701764              0          829.0
# Delhi           56089448              0         1267.0
# Mumbai          71322210              0         1579.0
# Kolkata         59078918              0         1146.0
# Jaipur          32488020              0          742.0
# Hyderabad       52001817              0          977.0
# Chennai         36434261              0         1013.0
# Cape Town        2745303              7          163.0
# Port Elizabeth   2745433              7          222.0
# Durban           5883117             15          192.0
# Centurion        4706622             12          130.0
# East London      1176627              3           94.0
# Johannesburg     3137799              8           60.0
# Kimberley        1176653              3           63.0
# Bloemfontein      784456              2           20.0
# ...

# %%
sortValue = df.sort_values("city",ascending=True)

# %%
sortValue.head()
# Out:
#           id       city        date player_of_match                 venue  \
# 405   729293  Abu Dhabi  2014-04-21        SK Raina  Sheikh Zayed Stadium
# 416   729315  Abu Dhabi  2014-04-29     JP Faulkner  Sheikh Zayed Stadium
# 412   729307  Abu Dhabi  2014-04-26  Sandeep Sharma  Sheikh Zayed Stadium
# 411   729305  Abu Dhabi  2014-04-26        PV Tambe  Sheikh Zayed Stadium
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis  Sheikh Zayed Stadium
#
#      neutral_venue                  team1                        team2  \
# 405              1    Chennai Super Kings             Delhi Daredevils
# 416              1  Kolkata Knight Riders             Rajasthan Royals
# 412              1  Kolkata Knight Riders              Kings XI Punjab
# 411              1       Rajasthan Royals  Royal Challengers Bangalore
# 814              0         Delhi Capitals          Sunrisers Hyderabad
#
#                toss_winner toss_decision               winner   result  \
# ...

# %%
 df.sort_values(['city'],ascending=False).groupby('city').head(3)
# Out:
#           id           city        date player_of_match  \
# 256   548314  Visakhapatnam  2012-04-09       RG Sharma
# 471   829731  Visakhapatnam  2015-04-18       JP Duminy
# 253   548311  Visakhapatnam  2012-04-07       RA Jadeja
# 764  1216500        Sharjah  2020-10-09        R Ashwin
# 804  1216540        Sharjah  2020-10-12  AB de Villiers
# ..       ...            ...         ...             ...
# 797  1216533      Abu Dhabi  2020-10-19      JC Buttler
# 809  1216545      Abu Dhabi  2020-09-26    Shubman Gill
# 399   729281            NaN  2014-04-17       YS Chahal
# 402   729287            NaN  2014-04-19        PA Patel
# 403   729289            NaN  2014-04-19       JP Duminy
#
#                                                  venue  neutral_venue  \
# 256  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...              0
# 471  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...              0
# 253  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...              0
# ...

# %%
#merge

#cancate

x = {
    'name':['A'],
    'age':[23],
    'gender':['M']
}

# %%
x
# Out:
# {'name': ['A'], 'age': [23], 'gender': ['M']}

# %%
y={
    'age':[34],
    'salary':[40000]
}
y
# Out:
# {'age': [34], 'salary': [40000]}

# %%
a = pd.DataFrame(x)

# %%
a
# Out:
#   name  age gender
# 0    A   23      M

# %%
b = pd.DataFrame(y)

# %%
b
# Out:
#    age  salary
# 0   34   40000

# %%
# merge
pd.merge(a,b,how='inner')
# Out:
# Empty DataFrame
# Columns: [name, age, gender, salary]
# Index: []

# %%
pd.merge(a,b,how='left')
# Out:
#   name  age gender  salary
# 0    A   23      M     NaN

# %%
pd.merge(a,b,how='right')
# Out:
#   name  age gender  salary
# 0  NaN   34    NaN   40000

# %%
pd.merge(a,b,how='outer')
# Out:
#   name  age gender   salary
# 0    A   23      M      NaN
# 1  NaN   34    NaN  40000.0
