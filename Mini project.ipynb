# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Satyam\Downloads\WD_DA_10am_11april-main\Automobile_data.csv')

# %%
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
# From the given dataset print the first and last five rows.
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df.tail()
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
# Clean the dataset and update the CSV file.


# check the null value
df.isnull().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
df.shape[0]
# Out:
# 61

# %%
df.corr()
# Out:
#                     index  wheel-base    length  horsepower  average-mileage  \
# index            1.000000    0.013401  0.004828   -0.093809         0.176037
# wheel-base       0.013401    1.000000  0.878381    0.463421        -0.547325
# length           0.004828    0.878381  1.000000    0.668555        -0.788429
# horsepower      -0.093809    0.463421  0.668555    1.000000        -0.808804
# average-mileage  0.176037   -0.547325 -0.788429   -0.808804         1.000000
# price           -0.197470    0.663085  0.788465    0.901707        -0.770217
#
#                     price
# index           -0.197470
# wheel-base       0.663085
# length           0.788465
# horsepower       0.901707
# average-mileage -0.770217
# price            1.000000

# %%
#percentage of data missing in the dataset.
df.isnull().mean()
# Out:
# index               0.00000
# company             0.00000
# body-style          0.00000
# wheel-base          0.00000
# length              0.00000
# engine-type         0.00000
# num-of-cylinders    0.00000
# horsepower          0.00000
# average-mileage     0.00000
# price               0.04918
# dtype: float64

# %%
df['price'].isnull().mean()
# Out:
# 0.04918032786885246

# %%
# Mean/Median/Mode
df.price.isnull().sum()
# Out:
# 3

# %%
# delete/ignore/random

# fillna---->bfill,ffill

df1 = df.fillna(df.price.mean())

# %%
df1.price.isnull().sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %%
df.price.mean()
# Out:
# 15387.0

# %%
# Find the most expensive car company name.
expensive_car = df1.groupby(['company'])[['price']].max()

# %%
expensive_car
# Out:
#                  price
# company
# alfa-romero    16500.0
# audi           18920.0
# bmw            41315.0
# chevrolet       6575.0
# dodge           6377.0
# honda          12945.0
# isuzu          15387.0
# jaguar         36000.0
# mazda          18344.0
# mercedes-benz  45400.0
# mitsubishi      8189.0
# nissan         13499.0
# porsche        37028.0
# toyota         15750.0
# volkswagen      9995.0
# volvo          13415.0

# %%
expensive_car.sort_values('price',ascending=False)
# Out:
#                  price
# company
# mercedes-benz  45400.0
# bmw            41315.0
# porsche        37028.0
# jaguar         36000.0
# audi           18920.0
# mazda          18344.0
# alfa-romero    16500.0
# toyota         15750.0
# isuzu          15387.0
# nissan         13499.0
# volvo          13415.0
# honda          12945.0
# volkswagen      9995.0
# mitsubishi      8189.0
# chevrolet       6575.0
# dodge           6377.0

# %%
df.loc[df['price']==df['price'].max(),['company']]
# Out:
#           company
# 35  mercedes-benz

# %%
expensive_car = df['price'].max()

# %%
df.loc[df['price'] == expensive_car,['company']]
# Out:
#           company
# 35  mercedes-benz

# %%
# Print All Toyota Cars details
df.loc[df['company']=='toyota']
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0

# %%
#  Count total cars per company.
df1['company'].value_counts()
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %%
#  Find each company’s Higesht price car
df1.groupby(["company"])[["price"]].max()
# Out:
#                  price
# company
# alfa-romero    16500.0
# audi           18920.0
# bmw            41315.0
# chevrolet       6575.0
# dodge           6377.0
# honda          12945.0
# isuzu          15387.0
# jaguar         36000.0
# mazda          18344.0
# mercedes-benz  45400.0
# mitsubishi      8189.0
# nissan         13499.0
# porsche        37028.0
# toyota         15750.0
# volkswagen      9995.0
# volvo          13415.0

# %%
car_manufacture = df.groupby(['company'])

# %%
car_manufacture[['price','body-style']].max()
# Out:
#                  price body-style
# company
# alfa-romero    16500.0  hatchback
# audi           18920.0      wagon
# bmw            41315.0      sedan
# chevrolet       6575.0      sedan
# dodge           6377.0  hatchback
# honda          12945.0      wagon
# isuzu           6785.0      sedan
# jaguar         36000.0      sedan
# mazda          18344.0      sedan
# mercedes-benz  45400.0      wagon
# mitsubishi      8189.0      sedan
# nissan         13499.0      wagon
# porsche        37028.0  hatchback
# toyota         15750.0      wagon
# volkswagen      9995.0      sedan
# volvo          13415.0      wagon

# %%
df.columns
# Out:
# Index(['index', 'company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')
